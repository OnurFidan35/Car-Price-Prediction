# %% [markdown]
# ## Araba Fiyat Tahmin Modeli(Car Price Prediction Model)

# %% [markdown]
# **Veriyi Anlayalım(Understanding Data)**

# %%
import pandas as pd
import numpy as py
import seaborn as sns

# %%
data=pd.read_csv("ilanlar.csv")
df=data.copy()
df.head()
# Out:
#     İlan No     İlan Tarihi    Marka     Seri                Model   Yıl  \
# 0  27502137  30 Aralık 2024  Renault   Symbol  1.5 dCi BlueDCI Joy  2018
# 1  27502169  30 Aralık 2024     Opel    Astra          1.6 Classic  2001
# 2  27314168  30 Aralık 2024   Toyota  Corolla              1.6 XEi  1997
# 3  27314158  30 Aralık 2024  Renault   Megane              1.6 RXT  2001
# 4  27501437  30 Aralık 2024     Fiat     Egea    1.6 Multijet Easy  2023
#
#     Kilometre     Vites Tipi    Yakıt Tipi    Kasa Tipi  ... Motor Hacmi  \
# 0  150.000 km            Düz         Dizel        Sedan  ...     1461 cc
# 1  323.000 km            Düz  LPG & Benzin  Hatchback/5  ...     1598 cc
# 2  390.000 km            Düz  LPG & Benzin        Sedan  ...     1587 cc
# 3  408.000 km            Düz  LPG & Benzin        Sedan  ...     1598 cc
# 4   72.651 km  Yarı Otomatik         Dizel        Sedan  ...     1598 cc
#
#   Motor Gücü        Çekiş Araç Durumu Ort. Yakıt Tüketimi Yakıt Deposu  \
# 0      90 hp  Önden Çekiş   İkinci El              3,9 lt        50 lt
# 1      75 hp  Önden Çekiş   İkinci El              7,2 lt        52 lt
# 2     105 hp  Önden Çekiş   İkinci El                 NaN        50 lt
# 3     107 hp  Önden Çekiş   İkinci El                7 lt        60 lt
# 4     120 hp  Önden Çekiş   İkinci El              3,9 lt        45 lt
#
#           Boya-değişen        Takasa Uygun     Kimden       Fiyat
# 0  1 değişen, 5 boyalı        Takasa Uygun  Galeriden  530.000 TL
# 1            10 boyalı  Takasa Uygun Değil  Galeriden  319.000 TL
# 2        Belirtilmemiş        Takasa Uygun  Galeriden  295.000 TL
# 3        Belirtilmemiş        Takasa Uygun  Galeriden  295.000 TL
# 4             1 boyalı        Takasa Uygun  Galeriden  919.000 TL
#
# [5 rows x 21 columns]

# %%
df.shape #21 Feature,2500 gözlem birimimiz olduğunu göruyoruz
# Out:
# (2500, 21)

# %%
df.info() #"Feauture"larımızın bir çoğu object tipinde olduğundan burada encoding dönüşümümleri yapmamız gerekecek.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   İlan No              2500 non-null   int64
#  1   İlan Tarihi          2500 non-null   object
#  2   Marka                2500 non-null   object
#  3   Seri                 2500 non-null   object
#  4   Model                2491 non-null   object
#  5   Yıl                  2500 non-null   int64
#  6   Kilometre            2500 non-null   object
#  7   Vites Tipi           2500 non-null   object
#  8   Yakıt Tipi           2500 non-null   object
#  9   Kasa Tipi            2498 non-null   object
#  10  Renk                 2500 non-null   object
#  11  Motor Hacmi          2464 non-null   object
#  12  Motor Gücü           2463 non-null   object
#  13  Çekiş                2471 non-null   object
#  14  Araç Durumu          2491 non-null   object
#  15  Ort. Yakıt Tüketimi  1844 non-null   object
#  16  Yakıt Deposu         2001 non-null   object
#  17  Boya-değişen         2500 non-null   object
#  18  Takasa Uygun         1878 non-null   object
#  19  Kimden               2500 non-null   object
#  20  Fiyat                2500 non-null   object
# dtypes: int64(2), object(19)
# memory usage: 410.3+ KB

# %%
for col in df.columns:
    print(col,df[col].unique())
# Out:
# İlan No [27502137 27502169 27314168 ... 27377242 27377222 27377214]
# İlan Tarihi ['30 Aralık 2024' '29 Aralık 2024' '28 Aralık 2024' '27 Aralık 2024'
#  '26 Aralık 2024' '25 Aralık 2024' '24 Aralık 2024' '23 Aralık 2024'
#  '22 Aralık 2024' '21 Aralık 2024' '20 Aralık 2024' '19 Aralık 2024'
#  '18 Aralık 2024' '17 Aralık 2024' '16 Aralık 2024' '15 Aralık 2024'
#  '14 Aralık 2024' '13 Aralık 2024' '12 Aralık 2024' '11 Aralık 2024'
#  '10 Aralık 2024' '09 Aralık 2024' '08 Aralık 2024' '07 Aralık 2024'
#  '06 Aralık 2024' '05 Aralık 2024' '04 Aralık 2024' '03 Aralık 2024'
#  '02 Aralık 2024' '01 Aralık 2024' '29 Kasım 2024' '27 Kasım 2024'
#  '26 Kasım 2024' '25 Kasım 2024' '23 Kasım 2024' '22 Kasım 2024'
#  '20 Kasım 2024' '19 Kasım 2024' '18 Kasım 2024' '17 Kasım 2024'
#  '16 Kasım 2024' '15 Kasım 2024' '14 Kasım 2024' '10 Kasım 2024'
#  '09 Kasım 2024' '31 Aralık 2024']
# Marka ['Renault' 'Opel' 'Toyota' 'Fiat' 'Volkswagen' 'Tofaş' 'Skoda' 'Hyundai'
#  'BMW' 'Ford' 'Mercedes - Benz' 'Peugeot' 'Audi' 'Seat' 'Volvo' 'Citroen'
#  'Nissan' 'Kia' 'Honda' 'Alfa Romeo' 'Chevrolet' 'Lancia' 'Daihatsu'
#  'Dacia' 'Porsche' 'DS Automobiles' 'Suzuki' 'Mazda' 'Jaguar' 'Lada'
#  'Anadol' 'Bugatti' 'MINI' 'Daewoo' 'Rover' 'Mitsubishi' 'Chrysler'
#  'Geely' 'Proton' 'Tata' 'Smart' 'Subaru']
# Seri ['Symbol' 'Astra' 'Corolla' 'Megane' 'Egea' 'Insignia' 'Passat' 'R 9'
#  'Şahin' 'Clio' 'Octavia' 'R 19' 'Jetta' 'Fabia' 'Getz' 'Golf' '5 Serisi'
#  'Focus' 'B' '308' 'C' 'A5' 'i20' 'Toledo' 'New Beetle' 'Palio' 'S40'
#  '301' 'C3' 'A' '3 Serisi' 'Linea' 'Yaris' 'Micra' 'Fiesta' 'Punto' 'R 12'
#  'Ceed' '4 Serisi' 'A6' 'SuperB' 'Accent' 'A4' 'Civic' 'Albea' 'Arteon'
#  'Fluence' 'Kartal' 'Polo' 'Vectra' 'C-Elysee' 'Sonata' 'Grand Scenic'
#  'Accent Blue' 'EOS' 'C-Max' 'Megane E-Tech' 'Giulietta' '1 Serisi'
#  'Cruze' 'Laguna' 'Scenic' 'VW CC' '508' 'A3' 'S60' 'Corsa' '200' 'Auris'
#  'Delta' 'Ibiza' 'Picanto' 'C4' 'i20 Troy' 'Copen' 'E' '250' '208' '207'
#  'Meriva' 'Leon' 'Sandero' '911' 'DS4' 'Lodgy' 'Verso' 'Doğan' 'C4 X' 'SL'
#  'Scirocco' 'i30' '306' '2 Serisi' '206' 'e-C4' 'Brava' 'C5' 'Logan'
#  'Accord' '500 Ailesi' 'Mustang' 'Lacetti' 'Mondeo' '307' 'Tipo' 'Pulsar'
#  'Accent Era' 'Bora' 'Swift' '2' 'X-Type' 'Taliant' 'VAZ' '407' 'Rio'
#  'A2 SL' 'Lantis' 'CLS' 'City' '626' 'Panamera' 'Siena' '323' '106' '159'
#  'Veyron' 'Cooper' 'Excel' 'Lanos' 'Cordoba' 'Elantra' 'Uno'
#  'Passat Variant' '147' 'Felicia' '416' 'Lancer' 'Sebring' 'Rapid' 'Murat'
#  'Aveo' 'Serçe' 'Almera' 'V40 Cross Country' 'Emgrand' 'One' 'Zafira'
#  'Avensis' 'Fusion' 'Idea' 'Primera' 'Sephia' 'Taurus' 'Altea' 'Carina'
#  'Vento' 'Samara' 'S90' 'Escort' '415' 'Colt' 'Marea' 'C4 Picasso' 'Panda'
#  'Cerato' 'Taunus' 'R 11' '406' '6 Serisi' 'Xsara' 'Marina' 'Stilo' 'Saxo'
#  'Spark' 'Indigo' '414' 'EQS' 'R 21' 'MX' 'CLA' '7 Serisi' '216'
#  'M Serisi' 'C2' 'i10' 'XE' 'Jazz' 'Corsa-e' 'Kalos' 'Tempra' 'V40'
#  'Z Serisi' 'Modus' '145' 'S' 'i Serisi' 'Matrix' 'ForFour' 'Impreza'
#  '300' '3']
# Model ['1.5 dCi BlueDCI Joy' '1.6 Classic' '1.6 XEi' '1.6 RXT'
#  '1.6 Multijet Easy' '1.6 CDTI Excellence' '1.3 Multijet Easy' '1.6 TDi'
#  '1.4 Broadway' '1.6' '1.5 dCi Grandtour Authentique' '1.6 TDI Ambiente'
#  '1.6 Europa RT' '1.4 TSi BlueMotion Comfortline' '1.0 GreenTec Style'
#  '1.4 DOHC AB AC' '1.6 RTE' '1.4 TSi Highline' '1.4 Broadway RN'
#  '520d Comfort' '1.6 Comfort' 'B 180 CDI BlueEFFICIENCY Style'
#  '1.5 dCi Alize' '1.6 Essentia' '1.6 VTi Comfort' 'C 200 AMG'
#  'A5 Sportback 2.0 TFSI Quattro' '1.4 MPI Elite' '1.6 Edition'
#  '1.3 Multijet Urban' '1.6 Signo Plus' '1.2 TSi Beetle' '1.5 TDCi Trend X'
#  '1.2 Go' '1.8' '1.5 BlueHDI Allure' '1.2 PureTech Feel'
#  '1.6 TDI Style CR' '1.5 dCi Icon' '1.5 dCi Joy'
#  'A 180 CDI BlueEFFICIENCY AMG Sport' '1.2 PureTech Allure' '1.33 Life'
#  '1.6 TDi BlueMotion Exclusive' '320i ED Sport Line' '1.4 RXT'
#  '1.6 TDCi Collection' '1.3 Multijet Active' '1.5 TDCi Titanium X'
#  '1.3 Multijet Pop' '1.33 Fun' '1.2 Match' 'A5 Sportback 2.0 TDI Quattro'
#  '1.4 TDCi Comfort' '1.6 HDi Active' '1.6 TDCi Trend X' '1.4 Dynamic'
#  '1.4 Authentique' 'Toros' '1.4 D-4D Elegant' '1.6 CRDi Concept Plus'
#  'C 200 D AMG' '420d xDrive M Sport' 'A6 Sedan 2.0 TDI Quattro'
#  '1.6 TDI Comfort' '1.6 TDI Optimal' '1.4 TSI Elegance' '1.6 Admire'
#  '1.6 TDCi Style' '1.3 TCe Joy' '316i M Sport' '1.4 Fire Easy'
#  'A4 Sedan 2.0 TDI' '1.4 CVVT Sense' '1.5 i-VTEC Elegance'
#  'Sole 1.3 Multijet Dynamic' '1.5 dCi Touch' '1.2 Joy' '2.0 TDI Elegance'
#  '1.0 TCe Equilibre' '1.6 TDi BlueMotion Highline' '1.6 i-VTEC Executive'
#  '1.6 TDi BlueMotion Comfortline' 'SLX' '1.2 TSi Comfortline' '2.0 GLS'
#  '1.4 D-4D Comfort Extra' 'A5 Sportback 1.4 TFSI' '1.6 Dynamique'
#  '1.6 TDi Trendline' '1.4 TDi Comfortline' '1.5 BlueHDi Feel' '2.0 GL'
#  '2.0 CRDi H-Matic' '1.5 dCi Privilege' '318i Prestige' '1.6 CRDI Mode'
#  '2.0 TDI Highline' '1.6 i-VTEC ES' '1.6 TDCi Titanium' '1.6 Enjoy Plus'
#  '1.2 Extreme' '1.2 TCe Touchrome' 'Iconic' '1.5 TDCi Titanium'
#  '1.8 T Comfortline' '1.6 HDi Premium' '1.4 TB MultiAir Distinctive'
#  '1.5 TSi Business' '116i Comfort' '1.6 LS' '1.6 Privilege'
#  '1.6 Comfort Extra' '1.5 dCi Sportway' '1.5 TSi Impression'
#  '1.2 Authentique' '1.6 BlueHDI Active' '1.0 IG-T Tekna' '1.4 MPI Jump'
#  '2.0 TDi 2.0 TDI' '1.6 CRDI Mode Plus' '1.5 Blue DCI Joy' '1.2 Dynamic'
#  'A3 Sedan 1.6 TDI Sport Line' '1.2 Mood' '1.4 Beymen Club'
#  '1.5 dCi Authentique' '1.6 D Premium' '1.2 Swing' '1.5 eTSI Style'
#  '0.9 TCe Joy' '1.4 T Cosmo' '1.4 D-4D Terra' '1.6 GT-Line'
#  '1.6 TDi Comfortline' '1.6 CD' 'D' '1.6 CRDI Biz' '1.0 TCe Joy'
#  '1.5 CRDi VGT' 'C 180 BlueEFFICIENCY Selection Plus' '1.4 Fire Lounge'
#  '1.6 i-VTEC ECO Elegance' '520i 50th Year M Edition' '1.4 Ambiente'
#  '1.6 MJet' '1.6 TDi BlueMotion Midline Plus' '1.3 Multijet Easy Plus'
#  '1.6 Advance' '1.4 TDi Trendline' '1.6 i-VTEC Eco Executive'
#  '320i M Sport' 'C 180 BlueEFFICIENCY Fascination'
#  'A3 Sedan 1.6 TDI Ambiente' '1.0 TCe Icon' '1.4 RNA' '1.0 EcoTSI Style'
#  '1.6 Comfortline' '1.25 EX' '1.4 Essentia' '1.6 HDi Allure'
#  '1.3 Multijet Dynamic' '1.6 BlueHDi Exclusive' '1.2 DOHC Mode'
#  '116d ED Sport Line' '1.5 Hybrid Cool' 'Grande 1.3 Multijet Active'
#  '1.4 Twinport Enjoy' '1.6 TDi BlueMotion Trendline'
#  '1.4 TSi BlueMotion Trendline' '1.5 EX' '1.3' 'A5 Coupe 1.8 TFSI'
#  '1.6 Trend' '1.4 TSi Comfortline' '2.0 TDi Comfortline' '1.6 Trendline'
#  '250 AMG' '1.5 dCi Expression' 'C 180 BlueEFFICIENCY AMG'
#  '1.6 FSi Comfortline' '1.0 TSi Life' 'Grande 1.4 Fire Active'
#  '1.2 PureTech Feel Bold' '1.2 PureTech Prime' '1.6 TDI Elegance'
#  'C 180 BlueEFFICIENCY Prime' '1.4 TDCi Trend' '1.4 Titanium'
#  '1.6 XEi Special' '1.6 Multijet Easy Plus'
#  'A3 Sportback 1.6 TDI Attraction' '1.4 HDi Attraction'
#  '1.6 Ti-VCT Collection' '1.6 VTi Premium' '1.4 Twinport Essentia'
#  '320i ED Modern Line' '1.2 TSi Allstar' '1.6 TDCi Ghia'
#  '1.5 e-Tec Premium' '250 TD' '1.6 TDI Ambition' '1.6 HDi SX'
#  '1.9 TDi Comfortline' '1.2 TSI Style' '1.5 dCi SportTourer Joy'
#  '118i Urban Line' '1.4 Fire Easy Plus' '418i Gran Coupe Prestige'
#  '1.5 dCi Stepway' '1.4 TDI Style' '1.4 TSi Midline' '1.6 TDI Xcellence'
#  '1.0T ECO-G Comfort' '1.4 D-4D Advance' '1.3 TCe Touch' 'Turbo S'
#  '1.5 BlueHDi Trocadero' '320i First Edition Sport Line'
#  '1.5 BlueDCI Ambiance' '1.8 Hybrid Dream' '1.3 Multijet Active Plus'
#  '1.6 Dream' '1.2 Ultimate' '1.2 Icon' '1.6 Touch' 'C 200 D Comfort'
#  '320d xDrive Techno Plus' '1.6 TDI CR Style' 'C 220 CDI Classic'
#  '1.6 Multijet Lounge' '1.5 Blue DCI Joy Comfort' '1.33 Terra' 'SLX ie'
#  '1.2 PureTech Shine' '280' '1.4 TSi Allstar'
#  '1.6 TDi BlueMotion Impression' '1.25 Flair' '250 CGI AMG Premium'
#  '320i ED Joy' '1.6 CRDi Style' 'A6 Sedan 3.0 Quattro' '1.6 Platinum'
#  '1.6 TDCi Titanium Grand' '200 CGI AMG' '1.2 Trendline'
#  '216d Gran Coupe First Edition Sport Line' '180 Elite' '1.6 Terra'
#  '1.6 i-VTEC Premium' '1.6 Twinport' '1.6 Alize' '200 d Exclusive'
#  '1.25 Ghia' '1.2 VTi Attraction' '1.3 CDTI Essentia'
#  '1.6 i-VTEC Elegance' '1.4 Fire Dynamic Sole' '1.6 TDi Highline'
#  '316i Comfort' 'A 180 CDI BlueEFFICIENCY AMG' '1.6 JTDM-2 Sprint'
#  '1.5 BlueHDi Shine' '1.5 eTSI R Line' '1.4 XT' 'Shine Bold'
#  'A3 Sportback 1.2 TFSI Attraction' '1.5 BlueHDI Active' '1.6 Ambiente'
#  'E' '1.4 Twinport Enjoy 111' '1.6 e-HDi Sportium'
#  '1.6 Multijet Urban Plus' '320i ED 40th Year Edition' '1.0 SCe Joy'
#  '1.6 Titanium' '1.5 i-VTEC Eco Executive Plus' '1.5 Blue DCI Touch'
#  '1.6 CRDi Premium' '1.4 Europa RNA' '320i ED Standart' '1.6 SX'
#  '1.0 TCe Evolution' '1.5 T3 Advance' 'L' '1.6 TDi BlueMotion Business'
#  '1.6 e-HDi Executive' '1.5 dCi MCV Ambiance' '1.6 Ti-VCT Style'
#  '1.6 Highline' '1.5 BlueDCI Touch' '320i ED Luxury Line Plus'
#  '1.3 Multijet Dynamic Sole' '1.4 Dynamique'
#  'A 180 BlueEFFICIENCY AMG Sport' '2.0 ES' '1.6 Linea Terra'
#  '1.5 TSI Premium' '500L 1.6 Mjet RockStar' '220 CDI BlueEFFICIENCY'
#  '1.6 Enjoy 111.Yıl' '1.3 Admire' '1.5 dCi Business' '1.6 TDI Prestige'
#  '1.6 Life' '1.6 CDTI Grand Sport Design' '1.3 Multijet Emotion'
#  '180 Exclusive' '180 Edition E' '1.0 Impression' '2.3 Fastback'
#  '1.0 Terra' 'C 180 AMG' '320i' '1.6 WTCC' '525d xDrive xDrive'
#  '1.6 Midline' '1.3 CDTI Enjoy Elegance' '2.0 TDCi Ghia' '0.9 TCe Touch'
#  '1.5 dCi Touch Plus' '1.6 HDi Feel' 'C 220 CDI Enerji' '1.4 HDi XR'
#  '1.6 S' '1.3 Multijet EL' '1.4 TSI FR' '1.5 Visia' '1.6 ie'
#  '1.5 TDCi Trend' '1.4 Team' '1.3 GLX' '1.5 High' '1.4 CRDi Jump'
#  '1.25 Trend X' '1.2 VTi Access' '1.6 Ghia' '1.4 Expression'
#  '1.4 Comfortline' '318i Premium Line' 'Şahin 5 Vites' '2.0 DTI Comfort'
#  'A6 Sedan 2.0 TDI' '316i Standart' '1.3 TCe Icon' '2.0 D High'
#  '1.4 HDi Access' '1.0 TSi Comfortline' '1.0 Tce Joy' '1.4 TSi Trendline'
#  '1.6 i-VTEC Dream' '1.6 XT' '2105' '2.0 GLX' '2.0 dCi Dynamique'
#  '1.4 SX ie' '320d Modern Line' 'C 180 Elegance'
#  '2.0 HDi Executive Premium' '1.6 i-DTEC Elegance' '1.5 CRDi Trend' nan
#  '1.2 MPI Cool' '1.6 Comfortline Classic' '1.5 Ti-VCT Trend X'
#  '1.8 Comfortline' '350' '1.2 TDi Trendline' '1.5 CRDi Admire'
#  '1.4 TSi BlueMotion Highline' '1.2 MPI Style' '1.4 Elite'
#  '1.6 Ti-VCT Trend X' '1.6 Multijet Mirror' '1.2 TDi BlueMotion'
#  '1.5 dCi Extreme Edition' '1.6 Collection' '1.2 PureTech GT' 'Diesel'
#  '1.6 TDI Style' 'B 180 CDI BlueEFFICIENCY Sport' '1.4 RTA' '1.8 GL'
#  '1.6 XR' '1.6 e-HDi Active' '1.6 TDCi Trend' '1.3 LX' '1.2 Street'
#  '1.4 TDCi Titanium X' '1.6 SLX' '1.3 Terra' '1.4 CVVT Elegance Tekno'
#  '1.5 Flame X-Pack' '1.6 HL' '1.5 i-VTEC Eco Elegance' '1.4 Broadway GTE'
#  '1.6 GLX' '1.4 Broadway RNi' 'A5 Sportback 40 TDI Quattro Sport' 'XN'
#  '1.9 JTD Progression' '180 AMG' '1.4 Fire Urban Plus' '1.4 Fire Urban'
#  '118i M Plus' '16.4' '1.6 CDTI Design' '1.3 CDTI Cosmo'
#  '1.2 TSI Reference' '1.4 T GTC Sport' '1.6 HDi Attraction' '116i Premium'
#  '1.6 Elegant' '1.4 T Sport' '1.6 Türkiye Paketi' '1.8 TDCi Comfort'
#  '1.4 EL' '1.6 Ti-VCT Trend' '1.4 RN' '1.6 i-VTEC LS' '1.4 CVVT Team'
#  '1.5 GLS' '2.0 TDCi Trend' '1.5 d Exclusive' '318i Standart'
#  '1.0 EcoBoost Titanium X' '1.5 SX' '1.6 CRDi Concept' '2.2 DTI Elegance'
#  '1.4 Comfort' '2.0 Sport' '1.9 TDi Primeline' '1.6 D' '1.4 TSI Ambition'
#  '1.4 TDI Stylance' '1.6 MPI Style' '1.4 HDi X' '1.6 Expression' '70 S'
#  '1.6 TDi Business' '1.6 Elegance' '1.4 Trendline' '1.5 CRDi GL Cool'
#  'A3 Sportback 1.6 Ambiente' 'C 200 D Exclusive' '1.6 Enjoy'
#  '1.6 E-Torq Lounge' '1.6 TS Progression' '1.5 dCi Elegance' '1.4 T Enjoy'
#  '1.3 GLXi' '1.6 Europa RNE' '1.6 HDi Confort' '1.2 MPI Team' 'Si'
#  '1.5 CRDi Team' '1.4 Stylance' 'A 180 CDI BlueEFFICIENCY Style'
#  '1.2 MPI Elite' '1.5 Invite' '1.6 i ES' '1.5 dCi SportTourer Icon'
#  '1.6 Essentia Konfor' '325Ci' '2.0 CRD Limited' '1.6 TDI Active'
#  'A4 Sedan 1.8 T' 'S' '1.3 Multijet Urban Plus' '1.2 EL' '2.0 Ghia'
#  '1.6 Primeline' 'Quicksilver' '131' '500 1.0 Hybrid Dolcevita'
#  '1.5 CRDi Mode' 'C 200 D Elegance' '1.3 D LT'
#  'B 180 CDI BlueEFFICIENCY Elite' '1.4 D-4D Comfort' '1.4 X-Design'
#  '1.3 CDTI Enjoy' '1.6 Europa RNA' '1.6 CRDi Prime' 'TSW' '1.5 GSL'
#  '1.6 HDi Comfort' '200' 'A6 Sedan 3.0 TDI Quattro' '1.4 TSi'
#  'Kartal 5 Vites' '525d xDrive Premium' '1.4 CVVT Mode Plus' '1.8 Comfort'
#  '1.3 GLS' '520d M Sport' '1.2 Twinport Essentia' '320d Techno Plus'
#  '1.6 CDTI Elite' '1.8 Elegant' '1.2 S' '1.4 Terra' '1.3 CDTI Enjoy 111'
#  '1.2 Essentia' '1.2 SL' '1.6 Technoplus' '1.4 SE' '1.4 Basicline'
#  '1.4 i S' '1.2 TSi BlueMotion Comfortline' '1.6 Cosmo' '1.6 Reference'
#  '1.6 Signo' '2.0 RXE' '520d Premium' '1.4 Fire Actual' '2.0 CD'
#  '180 Avantgarde' '1.6 Ti-VCT Titanium' '1.4 TDI Signo' '1.5 Dream'
#  '1.6 GTX' '3.0 V6 GL' '1.4 TSI Style XL' '1.6 Classic Twinport'
#  '1.4 Europa RT' '1.5 Tekna' '2.0 GLi' '1.6 CRDi Motion' '1.4 D-4D Linea'
#  '1.3 XL' '250 CGI BlueEFFICIENCY Avantgarde' '1.9 CL D'
#  '1.6 HDi Exclusive' '1.6 Sol' '1.6 WTCC Edition'
#  'C 180 Kompressor BlueEFFICIENCY AMG' 'A3 Sportback 1.4 TFSI' '1.4 ES'
#  '1.9 TDI Ambiente' '1.6 Authentique' '1.9 TDi Exclusive'
#  '1.6 Edition Plus' '2.0 100.Yıl' 'A6 Sedan 40 TDI Quattro Sport'
#  '2.0 D4 Inscription' '1.6 CL' '1.6 Dynamic' 'GLS'
#  'A6 Sedan 1.8 T Advance' '1.3 Invite' 'Sole 1.4 Fire Dynamic'
#  '1.6 Grandtour Dynamique' '1.2 Turbo Elegance'
#  'Grande 1.3 Multijet Emotion' '1.6 ELX' 'A 170 CDI Classic' 'TS'
#  '1.6 GLi' '1.6 HDi SX PK' '1.4 Fire Pop' '1.2 PureTech Live' '1.2 Enjoy'
#  '1.5 dCi Extreme' '1.5 Blue DCI Icon' 'A3 Sportback 1.6 TDI Ambition'
#  'A3 Sportback 1.6 TDI Ambiente' 'A3 Sedan 1.6 TDI Ambition'
#  'A5 Sportback 2.0 TDI' '1.5 Vision' 'B 150 Boyut' '428i xDrive M Sport'
#  '1.0 TCe Touch' '1.6 CDTI Edition' '1.6 CLX' '1.3 CDTI Active'
#  '1.6 BlueHdi Active' '1.6 Pacific' '1.6 Multijet Urban' '2.0 T'
#  '1.6 Extreme' '1.5 dCi Dynamique' '1.5 BlueHDi Feel Bold'
#  '1.6 e-HDi Confort Plus' '1.6 LS Plus' '0.9 TCe Icon' '1.4 Swing'
#  '1.6 Envy' '1.4 Fire Active' '2.0 CDTI Edition Elegance' '1.0 Style'
#  '1.6 CRDi EX' '328i Standart' '1.4 Stella' '2.0 GTS' '1.0 Trendline'
#  '1.6 Cabrio' 'Flash S' '1.8 TDCi Ghia' '1.2 Tekna' '420d Sport Line'
#  '1.6 CRDi Elite' '1.6 XLi' '1.4 Turbo Dynamic' '2.0 SV' '1.8 T Highline'
#  '1.4 SX' '1.6 TDi BlueMotion' 'A3 Sportback 1.6 Sportback Attraction'
#  '1.4 Extreme' '1.6 TDI Elegance CR' '1.3 CDTI Sport' '2.0 Executive'
#  '1.6 Vision' '0.9 TCe Stepway Easy-R' 'A3 Sportback 1.6 Ambition'
#  '1.3 ECO' '645Ci' '1.4 HDi' '2.0 Base' '1.4 HDi Fever' '1.4 HDi X Furio'
#  '1.6 HL Weekend' '1.4 TDI Comfort' '1.4 Mair Lounge S&S' '1.6 Actual'
#  '1.6 HDi Premium Plus' '1.5 i-VTEC Sport Plus' '1.9 TDI Elegance'
#  '1.5 1.5i GL' '1.5D SX' '1.4 X-Line' 'A3 Sedan 1.5 TFSI Dynamic' 'GLX'
#  '1.2 Classic' '1.0 SE' '1.9 Europa RNA TD' '1.4 TDI Trend' '1.4' '316'
#  '1.5 dCi Expression Plus' '1.4 Broadway RL' '450+' '318d Prestige'
#  '528i Standart' '2.0 TDi BlueMotion Comfortline' 'SL' '1.4 ie SX'
#  '1.9 Europa RN' 'GTE' '1.7 GTS Manager' '1.5 TDCi Active X' 'MX-5 1.5'
#  '1.6 RXE' 'C 200 d BlueTEC AMG' '520i M Sport' '180 D AMG'
#  '750i xDrive Long' '200 AMG+ 4Matic' '2.0 CDTI Edition' '1.6 D Dynamic'
#  '2.0 RXT' '1.6 BlueHDi Live' '1.4 Spring' '1.4 CRDi Fancy'
#  '1.4 HDi Trendy' '1.4 DOHC HY KLM' '1.2 T GS' 'C 200 Exclusive'
#  '1.2 Active' '520i Standart' '1.6 SLX ie' '320i Premium' '1.5 CRDi EX'
#  '1.6 GL' 'A4 Sedan 1.8 TFSI' '520i Special Edition Luxury Line'
#  '520i Luxury Line' 'A6 Sedan 40 TDI Quattro Advanced'
#  '0.9 TCe Sport Tourer Joy' '218i Gran Coupe First Edition Sport Line'
#  '2.0 TDI Laurin&Klement' '1.4 EcoTSI FR' '1.4 MPI Elite Smart'
#  '1.2 Twinport Enjoy 111' '1.5 GSL Premium SR' '1.2 Ambiente'
#  '1.4 TSi Exclusive' '116i M Sport' '520i Executive M Sport'
#  '1.5 TDCi Style' '1.6 Sport' '1.2 TSi Lounge' '1.5 dCi Grandtour Extreme'
#  '1.3 CDTI Business' 'M4' '1.3 Multijet Popstar'
#  'A6 Sedan 40 TDI Quattro Design' '116i Advantage' '1.4 Twinport Active'
#  '200 CGI BlueEFFICIENCY Avantgarde' '2.0 Dynamique' '1.6 Joy' '1.6 VTR'
#  '1.0 D-CVVT Style' '1.9 TDI Stella' '1.4 Style' '2.0' '1.5 D'
#  '2.0 D R-Sport Plus' 'C 200 d BlueTEC Style' '520i Premium'
#  '1.5 TSi R Line' '1.4 Fire Street' '1.4 GL'
#  '1.6 CDTI Exclusive Grand Sport' '1.0 eTSI Life' '1.4 Fun'
#  '1.6 TDCi Titanium X' '116d Joy Plus' '1.5 e-Tec Sportline'
#  '1.2 Turbo Ultimate' '1.4 Active' 'GS' '1.6 XL' '1.6 CRDi Team' '200 AMG'
#  '70 SX' '1.4 Reference' '1.4 TSi Sportline' '1.5 dCi Impressor'
#  '320i Cabrio' '116d One Edition' '1.4 HDi Active'
#  'A3 Sedan 35 TFSI Advanced' 'A3 Sedan 1.6 TDI Attraction'
#  '520i Special Edition M Sport' '1.0 MPI' '1.4 CVVT Prime' 'XR'
#  '1.4 Ambiance' '1.1 Trend X' '1.4 ie' '1.4 HDi Sporty'
#  '420d Gran Coupe M Sport' '1.6 Design Edition' '1.4 GLS'
#  '2.0 TDi Highline' '1.5 dCi Ambiance' '1.2 TSi BlueMotion Trendline'
#  '2.0 Sol' '320d Standart' '1.3 Sol' '1.6 Sportway' '1.6 HDi XS'
#  '320d M Sport' '1.6 SX AK SW' '1.3 MT 4X4' '1.6 D R-Design'
#  'Z4 2.0i sDrive' '1.6 CDTI Cosmo' '1.2 PureTech Active' '200 Elegance'
#  '1.4 EL Weekend' '1.6 e-HDi Dynamique' '1.9 JTD Distinctive Plus'
#  '1.4 D-4D Touch' '2.0 TDi BlueMotion Highline' '1.4 TS STD'
#  '740d xDrive Exclusive' '530i xDrive Executive M' 'A6 Sedan 2.0 TFSI'
#  '1.5 i-VTEC Executive Plus' 'A5 Sportback 2.0 TDI Quattro Design'
#  '1.6 Europa iE' '520d Prestige' '116i Sport Line' 'C 180 Sport'
#  'A4 Sedan 2.0 TDI Quattro Dynamic' '1.2 MPI Feel' '1.6 e-HDi Exclusive'
#  '520d xDrive Special Edition Luxury Line' '1.4 D-4D Sol' 'S 350 350 L'
#  '1.33 Fun Special Skypack' '1.5 dCi Black Line' '520i Comfort'
#  'i4 eDrive40 M Sport' '280 CDI Classic' '1.5' 'TX' '1.4 CVVT Cool'
#  '1.6 THP Access' '1.3 Multijet Mood' '1.4 Europa RN' '180 D Comfort'
#  '1.2 Turbo Edition' '1.4 TSI Style' '520i Executive'
#  'C 180 Kompressor BlueEfficiency Luxury' '1.8 Trendline' '1.6 GLS'
#  'EVO 1.3 Multijet Dynamic' '1.5 CDI Passion' 'Sole 1.3 Multijet Premio'
#  '1.4 Classic' '1.9 DTi RTE' '1.5 Vision Plus' '1.5 Signature'
#  '0.9 TCe TechRoad' '200 CDI Classic' 'i5 eDrive30 M Sport'
#  '1.0 eTSI Style' '1.3 CDTI Enjoy 111.Yıl' '1.5 Active'
#  'A3 Sportback 1.4 TFSI Attraction' 'A3 Sportback 30 TDI Sport'
#  'A3 Sedan 35 TFSI Sport' '1.2 PureTech Shine Bold' '1.4 Attraction'
#  'A4 Sedan 2.0 TDI Quattro' '1.5 d Elegance']
# Yıl [2018 2001 1997 2023 2022 2019 1994 1992 2012 2011 2016 2010 2015 2000
#  2014 2017 2005 2009 2004 2020 2008 2013 2007 1993 2006 2021 2024 1991
#  1989 1990 2003 1987 1998 1986 1999 2002 1996 1980 1988 1995 1984 1982
#  1985 1978]
# Kilometre ['150.000 km' '323.000 km' '390.000 km' '408.000 km' '72.651 km'
#  '70.000 km' '211.000 km' '65.000 km' '97.400 km' '325.000 km'
#  '111.111 km' '312.000 km' '127.000 km' '245.000 km' '269.000 km'
#  '52.000 km' '72.000 km' '217.000 km' '75.000 km' '300.000 km'
#  '176.000 km' '119.000 km' '175.000 km' '345.000 km' '184.048 km'
#  '113.000 km' '6.001 km' '248.000 km' '124.000 km' '102.296 km'
#  '379.000 km' '337.000 km' '105.000 km' '45.000 km' '190.000 km'
#  '350.000 km' '133.000 km' '43.000 km' '204.000 km' '137.000 km'
#  '180.000 km' '53.000 km' '61.000 km' '203.000 km' '140.000 km'
#  '230.000 km' '225.000 km' '237.000 km' '153.500 km' '146.000 km'
#  '50.350 km' '194.650 km' '270.000 km' '234.000 km' '221.000 km'
#  '132.000 km' '351.000 km' '281.000 km' '219.000 km' '170.000 km'
#  '261.000 km' '147.000 km' '157.000 km' '189.000 km' '110.000 km'
#  '69.000 km' '123.000 km' '40.000 km' '165.000 km' '197.000 km'
#  '195.000 km' '98.600 km' '15.000 km' '210.000 km' '177.000 km'
#  '34.000 km' '215.000 km' '89.500 km' '213.000 km' '87.000 km'
#  '324.000 km' '188.000 km' '56.500 km' '205.000 km' '103.000 km'
#  '23.500 km' '125.553 km' '100.000 km' '320.000 km' '236.000 km'
#  '288.000 km' '231.000 km' '271.000 km' '250.000 km' '285.000 km'
#  '200.000 km' '124.300 km' '102.900 km' '244.000 km' '125.000 km'
#  '138.000 km' '179.000 km' '7.000 km' '111.000 km' '329.000 km'
#  '249.000 km' '53.900 km' '122.000 km' '183.000 km' '290.000 km'
#  '209.000 km' '123.456 km' '96.000 km' '324.543 km' '231.250 km'
#  '201.000 km' '319.000 km' '99.000 km' '233.000 km' '19.000 km'
#  '240.000 km' '198.000 km' '81.000 km' '73.000 km' '241.250 km'
#  '151.750 km' '152.250 km' '280.000 km' '155.000 km' '394.000 km'
#  '309.000 km' '235.000 km' '268.000 km' '305.000 km' '30.000 km'
#  '42.000 km' '252.000 km' '226.000 km' '334.723 km' '232.000 km'
#  '239.800 km' '130.000 km' '56.300 km' '66.000 km' '318.000 km'
#  '299.999 km' '83.000 km' '62.000 km' '315.000 km' '148.000 km'
#  '274.000 km' '60.000 km' '35.000 km' '202.400 km' '181.000 km'
#  '131.000 km' '27.020 km' '208.000 km' '26.000 km' '258.200 km'
#  '301.530 km' '58.000 km' '94.000 km' '9.000 km' '17.000 km' '151.000 km'
#  '314.000 km' '97.000 km' '56.000 km' '125.500 km' '256.000 km'
#  '90.250 km' '85.000 km' '132.800 km' '317.000 km' '128.000 km'
#  '440.000 km' '199.850 km' '370.000 km' '28.000 km' '335.000 km'
#  '63.000 km' '6.100 km' '287.000 km' '133.500 km' '334.000 km' '76.183 km'
#  '189.550 km' '229.000 km' '112.500 km' '316.000 km' '136.000 km'
#  '295.000 km' '141.000 km' '19.900 km' '293.000 km' '316.125 km'
#  '149.000 km' '430.000 km' '297.000 km' '168.500 km' '64.350 km'
#  '120.500 km' '137.750 km' '89.000 km' '18.000 km' '156.850 km'
#  '246.000 km' '327.000 km' '75.689 km' '45.715 km' '91.460 km' '90.000 km'
#  '50.000 km' '79.500 km' '118.000 km' '220.000 km' '164.000 km'
#  '106.000 km' '143.000 km' '98.000 km' '17.500 km' '115.000 km'
#  '184.000 km' '275.000 km' '254.000 km' '163.000 km' '260.000 km'
#  '73.500 km' '208.500 km' '153.000 km' '35.400 km' '141.500 km'
#  '277.000 km' '182.000 km' '264.000 km' '139.000 km' '289.300 km'
#  '197.500 km' '59.600 km' '185.000 km' '112.000 km' '92.000 km'
#  '30.400 km' '24.500 km' '202.000 km' '500.000 km' '64.000 km'
#  '140.700 km' '95.000 km' '169.000 km' '126.000 km' '121.000 km'
#  '41.190 km' '167.000 km' '210.350 km' '20.250 km' '223.000 km'
#  '161.000 km' '59.000 km' '171.000 km' '164.500 km' '74.000 km'
#  '116.000 km' '384.000 km' '199.000 km' '282.387 km' '185.636 km'
#  '228.000 km' '310.000 km' '52.828 km' '292.000 km' '109.650 km'
#  '154.000 km' '191.000 km' '218.000 km' '107.600 km' '196.000 km'
#  '93.000 km' '158.000 km' '6.500 km' '302.000 km' '289.000 km'
#  '253.000 km' '158.800 km' '255.757 km' '298.000 km' '120.000 km'
#  '330.000 km' '42.600 km' '162.000 km' '160.000 km' '98.935 km'
#  '344.000 km' '14.230 km' '22.190 km' '193.000 km' '306.000 km'
#  '263.500 km' '170.250 km' '82.000 km' '251.000 km' '68.000 km'
#  '57.000 km' '279.000 km' '263.000 km' '55.653 km' '101.700 km'
#  '135.000 km' '340.000 km' '24.578 km' '136.178 km' '299.000 km'
#  '74.330 km' '112.964 km' '174.025 km' '9.890 km' '86.200 km' '264.350 km'
#  '495.000 km' '67.544 km' '238.000 km' '410.000 km' '67.000 km'
#  '276.285 km' '42.015 km' '30.500 km' '420.000 km' '283.000 km'
#  '400.000 km' '91.800 km' '76.000 km' '58.500 km' '44.144 km' '365.000 km'
#  '142.075 km' '267.000 km' '217.700 km' '198.750 km' '8.200 km'
#  '135.500 km' '156.998 km' '355.000 km' '83.500 km' '152.000 km'
#  '166.000 km' '49.000 km' '75.400 km' '39.000 km' '10.000 km' '22.500 km'
#  '360.000 km' '443.000 km' '243.000 km' '94.500 km' '77.000 km'
#  '71.600 km' '156.000 km' '7.600 km' '375.000 km' '146.600 km'
#  '193.500 km' '276.000 km' '215.500 km' '296.000 km' '257.000 km'
#  '275.650 km' '93.500 km' '250.001 km' '267.800 km' '31.000 km'
#  '12.000 km' '206.000 km' '169.500 km' '349.000 km' '278.000 km'
#  '185.750 km' '142.000 km' '33.000 km' '88.500 km' '266.000 km'
#  '12.500 km' '222.300 km' '245.500 km' '65.500 km' '183.500 km'
#  '185.500 km' '84.500 km' '207.000 km' '134.000 km' '207.700 km'
#  '294.000 km' '104.000 km' '251.450 km' '187.000 km' '137.221 km'
#  '159.000 km' '71.000 km' '192.000 km' '178.000 km' '372.000 km'
#  '152.500 km' '107.000 km' '385.000 km' '354.000 km' '970.000 km'
#  '87.900 km' '223.200 km' '690.000 km' '7.955 km' '347.677 km' '13.596 km'
#  '109.000 km' '416.000 km' '216.000 km' '241.000 km' '88.480 km'
#  '259.600 km' '229.500 km' '415.000 km' '186.000 km' '198.600 km'
#  '255.000 km' '99.999 km' '448.000 km' '258.000 km' '69.500 km'
#  '273.000 km' '242.000 km' '129.000 km' '226.213 km' '191.500 km'
#  '489.000 km' '383.000 km' '79.000 km' '246.425 km' '95.500 km'
#  '222.000 km' '214.000 km' '80.000 km' '88.000 km' '145.000 km'
#  '16.000 km' '93.300 km' '380.000 km' '299.500 km' '8.000 km' '10.350 km'
#  '155.214 km' '389.000 km' '19.800 km' '270.500 km' '174.924 km'
#  '20.000 km' '200.001 km' '212.000 km' '326.000 km' '37.000 km'
#  '232.512 km' '128.500 km' '84.000 km' '272.000 km' '92.330 km'
#  '22.850 km' '265.000 km' '999.999 km' '359.000 km' '46.922 km'
#  '157.256 km' '91.000 km' '321.500 km' '262.000 km' '38.426 km'
#  '282.600 km' '168.000 km' '25.000 km' '21.950 km' '200.751 km'
#  '286.000 km' '293.900 km' '149.450 km' '149.600 km' '126.611 km'
#  '118.500 km' '333.000 km' '249.500 km' '16.918 km' '24.000 km'
#  '328.000 km' '247.000 km' '208.456 km' '209.500 km' '166.500 km'
#  '270.155 km' '303.000 km' '378.000 km' '130.100 km' '291.000 km'
#  '99.400 km' '80.288 km' '643.000 km' '152.580 km' '81.794 km' '38.800 km'
#  '374.000 km' '126.700 km' '157.625 km' '10.700 km' '309.600 km'
#  '108.000 km' '216.030 km' '57.200 km' '48.500 km' '249.700 km'
#  '268.500 km' '281.500 km' '90.500 km' '361.500 km' '160.500 km'
#  '78.605 km' '215.100 km' '55.000 km' '101.000 km' '70.600 km'
#  '343.500 km' '220.833 km' '19.053 km' '44.425 km' '92.500 km'
#  '138.750 km' '433.000 km' '94.580 km' '355.555 km' '11.111 km'
#  '556.000 km' '80.789 km' '219.500 km' '912.240 km' '57.900 km'
#  '259.580 km' '149.850 km' '46.000 km' '391.800 km' '300.480 km'
#  '170.800 km' '164.400 km' '149.250 km' '650.000 km' '456.000 km'
#  '236.500 km' '41.000 km' '99.500 km' '301.000 km' '227.000 km'
#  '86.000 km' '307.000 km' '361.000 km' '129.420 km' '38.300 km'
#  '284.000 km' '121.300 km' '156.500 km' '24.900 km' '435.000 km'
#  '48.000 km' '102.300 km' '106.500 km' '46.500 km' '23.000 km'
#  '239.000 km' '198.500 km' '22.300 km' '252.565 km' '97.650 km'
#  '163.150 km' '259.000 km' '47.000 km' '104.500 km' '178.850 km'
#  '126.400 km' '31.100 km' '8.150 km' '366.000 km' '109.752 km' '9.600 km'
#  '96.500 km' '22.000 km' '13.000 km' '102.000 km' '35.800 km' '34.150 km'
#  '190.500 km' '480.000 km' '102.500 km' '224.000 km' '233.854 km'
#  '49.500 km' '253.685 km' '289.985 km' '367.000 km' '17.566 km'
#  '194.000 km' '398.000 km' '55.500 km' '425.000 km' '176.500 km'
#  '117.777 km' '427.000 km' '187.200 km' '117.600 km' '168.734 km'
#  '13.500 km' '357.000 km' '26.537 km' '150.500 km' '174.000 km'
#  '328.500 km' '233.500 km' '442.000 km' '36.000 km' '387.000 km'
#  '205.900 km' '19.400 km' '235.880 km' '15.401 km' '66.299 km'
#  '270.771 km' '23.339 km' '32.000 km' '81.500 km' '127.112 km'
#  '388.000 km' '268.100 km' '22.782 km' '19.809 km' '24.400 km'
#  '268.566 km' '98.892 km' '141.800 km' '199.542 km' '298.500 km'
#  '51.500 km' '308.000 km' '201.111 km' '243.500 km' '534.000 km'
#  '21.600 km' '131.682 km' '230.840 km' '12.206 km' '177.500 km'
#  '138.890 km' '6.099 km' '143.500 km' '99.950 km' '117.000 km' '44.000 km'
#  '19.335 km' '173.000 km' '461.000 km' '149.800 km']
# Vites Tipi ['Düz' 'Yarı Otomatik' 'Otomatik']
# Yakıt Tipi ['Dizel' 'LPG & Benzin' 'Benzin' 'Elektrik' 'Hibrit']
# Kasa Tipi ['Sedan' 'Hatchback/5' 'Station wagon' 'MPV' 'Hatchback/3' '-' nan 'Coupe'
#  'Roadster' 'Cabrio']
# Renk ['Beyaz' 'Siyah' 'Gri (Gümüş)' 'Bordo' 'Gri' 'Füme' 'Kırmızı'
#  'Mavi (metalik)' 'Mavi' 'Gri (metalik)' 'Gri (titanyum)' 'Lacivert'
#  'Turuncu' 'Kahverengi' 'Bej' 'Yeşil' 'Turkuaz' 'Şampanya'
#  'Yeşil (metalik)' 'Altın' 'Diğer' 'Sarı' 'Mor']
# Motor Hacmi ['1461 cc' '1598 cc' '1587 cc' '1248 cc' '1390 cc' '1581 cc'
#  '1401 - 1600 cm3' '1201 - 1400 cm3' '999 cc' '1399 cc' '1395 cc'
#  '1995 cc' '1596 cc' '1496 cc' '1984 cc' '1368 cc' '1197 cc' '1500 cc'
#  '1242 cc' '1798 cc' '1499 cc' '1199 cc' '1329 cc' '1198 cc'
#  '1801 - 2000 cm3' '1560 cc' '1397 cc' '1364 cc' '1582 cc' '1968 cc'
#  '1599 cc' '1332 cc' '1396 cc' '1498 cc' '1149 cc' '1597 cc' '1998 cc'
#  '1497 cc' '1422 cc' '1991 cc' '1590 cc' '1400 cc' nan '1601 - 1800 cm3'
#  '898 cc' '1997 cc' '1595 cc' '1796 cc' "1200 cm3' e kadar" '1398 cc'
#  '1493 cc' '1298 cc' '2501 - 3000 cm3' '1388 cc' '2001 - 2500 cm3'
#  '1896 cc' '3800 cc' '1600 cc' '2148 cc' '2996 cc' '1753 cc' '2976 cc'
#  '1360 cc' '-' '998 cc' '1341 cc' '2300 cc' '2143 cc' '1988 cc' '1372 cc'
#  '1799 cc' '1840 cc' '1781 cc' '3498 cc' '1339 cc' '1576 cc' '2967 cc'
#  '1296 cc' '1580 cc' '1124 cc' '1910 cc' '7993 cc' '1468 cc' '2171 cc'
#  '1591 cc' '1289 cc' '1589 cc' '2494 cc' '1297 cc' '1239 cc' '1495 cc'
#  '1229 cc' '1490 cc' '1689 cc' '1300 cc' '1389 cc' '1956 cc' '2793 cc'
#  '1993 cc' '1721 cc' '4398 cc' '1405 cc' '1527 cc' '995 cc' '1766 cc'
#  '1870 cc' '4395 cc' '2497 cc' '1592 cc' '1251 cc' '1999 cc' '1084 cc'
#  '1328 cc' '2993 cc' '2931 cc']
# Motor Gücü ['90 hp' '75 hp' '105 hp' '107 hp' '120 hp' '130 hp' '136 hp' '95 hp'
#  '83 hp' '51 - 75 HP' '101 - 125 HP' '110 hp' '97 hp' '125 hp' '190 hp'
#  '100 hp' '65 hp' '115 hp' '122 hp' '204 hp' '211 hp' '81 hp' '102 hp'
#  '126 - 150 HP' '109 hp' '132 hp' '99 hp' '170 hp' '98 hp' '80 hp'
#  '176 - 200 HP' '68 hp' '93 hp' '76 - 100 HP' '72 hp' '184 hp' '112 hp'
#  '140 hp' '177 hp' '182 hp' '70 hp' '150 hp' '601 HP ve üzeri' '220 hp'
#  '116 hp' '113 hp' '86 hp' '92 hp' '124 hp' '156 hp' '151 - 175 HP'
#  '106 hp' '85 hp' '78 hp' '74 hp' '87 hp' '77 hp' '101 hp' '96 hp'
#  '580 hp' '143 hp' '231 hp' '60 hp' '201 - 225 HP' '160 hp' '73 hp'
#  '91 hp' '114 hp' '129 hp' '103 hp' '152 hp' '117 hp' '111 hp' '317 hp'
#  '218 hp' '69 hp' nan '82 hp' '-' '138 hp' "50 HP'ye kadar" '84 hp'
#  '123 hp' '272 hp' '300 hp' '88 hp' '67 hp' '61 hp' '1001 hp' '128 hp'
#  '71 hp' '127 hp' '192 hp' '76 hp' '245 hp' '108 hp' '121 hp' '147 hp'
#  '276 - 300 HP' '126 hp' '131 hp' '64 hp' '54 hp' '326 - 350 HP' '180 hp'
#  '193 hp' '134 hp' '333 hp' '94 hp' '58 hp' '66 hp' '407 hp' '163 hp'
#  '426 - 450 HP' '306 hp' '252 hp' '226 - 250 HP' '141 hp' '158 hp' '55 hp'
#  '118 hp']
# Çekiş ['Önden Çekiş' 'Arkadan İtiş' '4WD (Sürekli)' '-' nan]
# Araç Durumu ['İkinci El' nan]
# Ort. Yakıt Tüketimi ['3,9 lt' '7,2 lt' nan '7 lt' '4,4 lt' '5,1 lt' '4,1 lt' '4 lt' '4,6 lt'
#  '6,7 lt' '5,2 lt' '4,7 lt' '6,3 lt' '6,6 lt' '6,4 lt' '6,5 lt' '7,1 lt'
#  '6,9 lt' '5,9 lt' '4,5 lt' '4,2 lt' '3,7 lt' '5,8 lt' '5,3 lt' '4,9 lt'
#  '3,8 lt' '5,4 lt' '6 lt' '4,3 lt' '6,1 lt' '8 lt' '4,8 lt' '5,5 lt'
#  '5,7 lt' '3,5 lt' '3,6 lt' '7,3 lt' '5 lt' '5,6 lt' '6,8 lt' '7,5 lt'
#  '7,8 lt' '7,4 lt' '6,2 lt' '7,7 lt' '9,1 lt' '9,4 lt' '11,3 lt' '7,9 lt'
#  '10 lt' '8,6 lt' '9,8 lt' '8,1 lt' '8,8 lt' '8,3 lt' '9 lt' '10,1 lt'
#  '3,4 lt' '8,7 lt' '23,5 lt' '8,2 lt' '9,5 lt' '7,6 lt' '8,4 lt' '8,5 lt'
#  '9,2 lt' '10,9 lt' '10,5 lt' '11,9 lt' '9,9 lt' '10,3 lt' '9,6 lt']
# Yakıt Deposu ['50 lt' '52 lt' '60 lt' '45 lt' '62 lt' '59 lt' '47 lt' '55 lt' nan
#  '70 lt' '61 lt' '56 lt' '51 lt' '49 lt' '42 lt' '41 lt' '53 lt' '57 lt'
#  '65 lt' '66 lt' '63 lt' '48 lt' '54 lt' '43 lt' '68 lt' '58 lt' '46 lt'
#  '67 lt' '35 lt' '36 lt' '40 lt' '64 lt' '44 lt' '80 lt' '71 lt' '39 lt'
#  '100 lt' '75 lt' '82 lt' '90 lt' '72 lt']
# Boya-değişen ['1 değişen, 5 boyalı' '10 boyalı' 'Belirtilmemiş' '1 boyalı'
#  'Tamamı orjinal' '4 boyalı' '2 boyalı' '3 boyalı' '7 boyalı'
#  '1 değişen, 3 boyalı' '1 değişen' '2 değişen, 3 boyalı' '9 boyalı'
#  '1 değişen, 1 boyalı' '2 değişen' '1 değişen, 2 boyalı' 'Tamamı boyalı'
#  '2 değişen, 4 boyalı' '1 değişen, 4 boyalı' '3 değişen, 1 boyalı'
#  '2 değişen, 8 boyalı' '4 değişen' '5 boyalı' '3 değişen'
#  '5 değişen, 2 boyalı' '1 değişen, 6 boyalı' '1 değişen, 9 boyalı'
#  '2 değişen, 2 boyalı' '4 değişen, 9 boyalı' '3 değişen, 6 boyalı'
#  '1 değişen, 8 boyalı' '2 değişen, 1 boyalı' '8 boyalı'
#  '1 değişen, 7 boyalı' '2 değişen, 6 boyalı' '6 boyalı'
#  '3 değişen, 2 boyalı' '2 değişen, 10 boyalı' '2 değişen, 9 boyalı'
#  '2 değişen, 7 boyalı' '1 değişen, 11 boyalı' '4 değişen, 5 boyalı'
#  '3 değişen, 5 boyalı' '4 değişen, 3 boyalı' '1 değişen, 12 boyalı'
#  '3 değişen, 8 boyalı' '6 değişen, 5 boyalı' '1 değişen, 10 boyalı'
#  '4 değişen, 4 boyalı' '11 boyalı' '3 değişen, 7 boyalı'
#  '2 değişen, 5 boyalı' '2 değişen, 11 boyalı' '12 boyalı'
#  '3 değişen, 3 boyalı' '3 değişen, 4 boyalı' '4 değişen, 2 boyalı'
#  '5 değişen, 3 boyalı' '7 değişen, 2 boyalı' '6 değişen, 7 boyalı'
#  '3 değişen, 10 boyalı' '3 değişen, 9 boyalı' '4 değişen, 8 boyalı'
#  '5 değişen, 6 boyalı' '5 değişen, 4 boyalı' '4 değişen, 7 boyalı']
# Takasa Uygun ['Takasa Uygun' 'Takasa Uygun Değil' nan '-']
# Kimden ['Galeriden' 'Sahibinden' 'Yetkili Bayiden']
# Fiyat ['530.000 TL' '319.000 TL' '295.000 TL' '919.000 TL' '925.000 TL'
#  '1.150.000 TL' '785.000 TL' '1.399.500 TL' '133.000 TL' '128.000 TL'
#  '415.000 TL' '760.000 TL' '245.500 TL' '729.900 TL' '985.000 TL'
#  '558.000 TL' '465.000 TL' '945.000 TL' '235.000 TL' '1.565.000 TL'
#  '659.750 TL' '1.159.000 TL' '330.000 TL' '565.000 TL' '500.000 TL'
#  '3.289.900 TL' '1.300.000 TL' '835.000 TL' '755.000 TL' '680.000 TL'
#  '290.000 TL' '360.000 TL' '699.750 TL' '1.240.000 TL' '335.000 TL'
#  '375.000 TL' '699.000 TL' '739.000 TL' '960.000 TL' '1.089.000 TL'
#  '498.000 TL' '1.450.000 TL' '1.239.900 TL' '709.900 TL' '975.000 TL'
#  '950.000 TL' '1.080.000 TL' '469.000 TL' '1.365.000 TL' '1.200.000 TL'
#  '468.750 TL' '625.000 TL' '700.000 TL' '765.980 TL' '365.000 TL'
#  '520.000 TL' '635.000 TL' '440.000 TL' '285.000 TL' '150.000 TL'
#  '175.000 TL' '540.000 TL' '889.999 TL' '1.400.000 TL' '1.465.000 TL'
#  '2.310.000 TL' '1.010.000 TL' '539.000 TL' '788.000 TL' '299.800 TL'
#  '849.750 TL' '1.025.000 TL' '1.298.000 TL' '725.000 TL' '579.750 TL'
#  '1.625.000 TL' '385.000 TL' '915.000 TL' '288.000 TL' '728.000 TL'
#  '2.145.000 TL' '995.000 TL' '1.425.000 TL' '670.000 TL' '695.000 TL'
#  '610.000 TL' '880.000 TL' '130.000 TL' '868.000 TL' '185.000 TL'
#  '2.300.000 TL' '3.200.000 TL' '395.000 TL' '743.750 TL' '809.000 TL'
#  '820.000 TL' '630.000 TL' '134.999 TL' '224.999 TL' '460.000 TL'
#  '1.280.000 TL' '1.550.000 TL' '475.000 TL' '497.000 TL' '675.000 TL'
#  '1.320.000 TL' '409.000 TL' '839.750 TL' '1.350.000 TL' '1.189.000 TL'
#  '455.000 TL' '479.000 TL' '750.000 TL' '1.635.000 TL' '739.900 TL'
#  '469.900 TL' '339.000 TL' '155.000 TL' '1.148.000 TL' '400.000 TL'
#  '1.239.000 TL' '1.035.000 TL' '270.000 TL' '1.285.000 TL' '1.485.000 TL'
#  '495.000 TL' '980.000 TL' '838.000 TL' '612.500 TL' '990.000 TL'
#  '1.385.000 TL' '320.000 TL' '1.129.750 TL' '998.000 TL' '225.000 TL'
#  '575.000 TL' '425.000 TL' '195.000 TL' '355.000 TL' '449.000 TL'
#  '865.000 TL' '250.000 TL' '1.490.000 TL' '657.500 TL' '550.000 TL'
#  '745.000 TL' '433.000 TL' '735.000 TL' '685.000 TL' '380.000 TL'
#  '854.900 TL' '345.000 TL' '655.000 TL' '3.290.000 TL' '1.119.000 TL'
#  '649.000 TL' '705.000 TL' '509.000 TL' '1.100.000 TL' '2.730.000 TL'
#  '939.750 TL' '1.020.000 TL' '997.900 TL' '480.000 TL' '467.500 TL'
#  '534.000 TL' '300.000 TL' '970.000 TL' '875.000 TL' '145.000 TL'
#  '340.000 TL' '645.000 TL' '397.000 TL' '1.299.000 TL' '779.750 TL'
#  '798.000 TL' '919.950 TL' '914.950 TL' '580.000 TL' '220.000 TL'
#  '710.000 TL' '454.500 TL' '845.000 TL' '1.078.000 TL' '935.000 TL'
#  '626.900 TL' '1.265.000 TL' '269.000 TL' '499.000 TL' '695.950 TL'
#  '595.000 TL' '665.000 TL' '1.950.000 TL' '357.500 TL' '299.000 TL'
#  '1.175.000 TL' '417.500 TL' '1.105.000 TL' '275.000 TL' '910.000 TL'
#  '1.045.750 TL' '925.900 TL' '490.000 TL' '1.319.000 TL' '379.000 TL'
#  '879.000 TL' '795.000 TL' '383.500 TL' '585.000 TL' '640.000 TL'
#  '779.500 TL' '350.000 TL' '1.074.500 TL' '848.000 TL' '1.555.000 TL'
#  '245.000 TL' '799.750 TL' '560.000 TL' '543.000 TL' '347.500 TL'
#  '765.000 TL' '219.000 TL' '665.900 TL' '1.614.900 TL' '510.000 TL'
#  '647.000 TL' '665.950 TL' '1.138.000 TL' '20.750.000 TL' '1.649.900 TL'
#  '2.189.950 TL' '779.000 TL' '649.900 TL' '588.000 TL' '567.500 TL'
#  '399.750 TL' '1.145.000 TL' '890.000 TL' '1.530.000 TL' '790.000 TL'
#  '1.170.000 TL' '482.000 TL' '1.015.000 TL' '882.750 TL' '775.000 TL'
#  '549.000 TL' '1.315.000 TL' '892.500 TL' '4.052.900 TL' '939.000 TL'
#  '1.065.000 TL' '438.000 TL' '1.368.000 TL' '1.401.000 TL' '383.000 TL'
#  '799.000 TL' '730.000 TL' '1.449.000 TL' '1.650.000 TL' '870.000 TL'
#  '698.000 TL' '615.900 TL' '338.000 TL' '435.000 TL' '4.000.000 TL'
#  '252.500 TL' '789.900 TL' '895.000 TL' '1.049.900 TL' '570.000 TL'
#  '1.124.000 TL' '1.560.000 TL' '1.195.000 TL' '584.700 TL' '2.460.000 TL'
#  '855.000 TL' '1.250.000 TL' '329.000 TL' '886.000 TL' '789.000 TL'
#  '1.825.000 TL' '449.750 TL' '666.000 TL' '810.000 TL' '1.715.000 TL'
#  '1.050.000 TL' '955.000 TL' '240.000 TL' '1.049.000 TL' '1.249.900 TL'
#  '159.999 TL' '860.000 TL' '1.497.500 TL' '620.000 TL' '940.000 TL'
#  '548.000 TL' '484.000 TL' '859.000 TL' '430.000 TL' '525.000 TL'
#  '555.000 TL' '534.750 TL' '1.420.000 TL' '308.000 TL' '329.500 TL'
#  '409.900 TL' '420.000 TL' '770.000 TL' '1.449.500 TL' '748.000 TL'
#  '889.000 TL' '1.975.000 TL' '179.000 TL' '143.750 TL' '749.000 TL'
#  '5.550.000 TL' '905.000 TL' '4.100.000 TL' '485.000 TL' '1.184.500 TL'
#  '499.999 TL' '405.000 TL' '1.495.000 TL' '505.000 TL' '545.000 TL'
#  '598.000 TL' '180.000 TL' '800.000 TL' '305.000 TL' '452.500 TL'
#  '1.069.900 TL' '920.000 TL' '1.000.000 TL' '200.000 TL' '474.750 TL'
#  '557.500 TL' '450.000 TL' '769.900 TL' '998.500 TL' '1.499.500 TL'
#  '740.000 TL' '1.430.000 TL' '138.000 TL' '599.000 TL' '325.000 TL'
#  '1.345.000 TL' '965.000 TL' '515.000 TL' '999.900 TL' '759.900 TL'
#  '615.000 TL' '589.000 TL' '815.000 TL' '260.000 TL' '878.900 TL'
#  '1.375.000 TL' '1.765.000 TL' '900.000 TL' '265.000 TL' '1.339.000 TL'
#  '289.000 TL' '1.185.000 TL' '210.000 TL' '283.000 TL' '650.000 TL'
#  '229.000 TL' '529.000 TL' '476.000 TL' '1.349.000 TL' '1.369.000 TL'
#  '547.500 TL' '1.199.000 TL' '720.000 TL' '3.950.000 TL' '1.099.000 TL'
#  '470.000 TL' '132.500 TL' '780.000 TL' '682.000 TL' '535.000 TL'
#  '255.000 TL' '458.000 TL' '979.000 TL' '590.000 TL' '1.990.000 TL'
#  '1.275.000 TL' '244.000 TL' '1.599.000 TL' '137.500 TL' '164.000 TL'
#  '394.000 TL' '374.000 TL' '624.000 TL' '114.000 TL' '217.500 TL'
#  '324.000 TL' '2.690.000 TL' '1.140.000 TL' '674.000 TL' '1.660.000 TL'
#  '692.500 TL' '600.000 TL' '660.000 TL' '98.000.000 TL' '850.000 TL'
#  '605.000 TL' '215.000 TL' '390.000 TL' '205.000 TL' '1.680.000 TL'
#  '410.000 TL' '1.165.000 TL' '1.135.000 TL' '190.000 TL' '369.000 TL'
#  '2.290.000 TL' '428.500 TL' '825.000 TL' '388.000 TL' '885.000 TL'
#  '488.000 TL' '1.030.000 TL' '1.270.000 TL' '715.000 TL' '478.000 TL'
#  '262.000 TL' '532.000 TL' '1.180.000 TL' '1.500.000 TL' '135.000 TL'
#  '188.888 TL' '85.000 TL' '399.000 TL' '379.900 TL' '389.000 TL'
#  '699.900 TL' '280.000 TL' '140.000 TL' '315.000 TL' '370.000 TL'
#  '1.585.000 TL' '178.000 TL' '689.000 TL' '108.000 TL' '1.070.000 TL'
#  '159.750 TL' '287.000 TL' '267.500 TL' '2.225.000 TL' '1.300.900 TL'
#  '252.000 TL' '1.220.000 TL' '1.190.000 TL' '165.000 TL' '2.360.000 TL'
#  '1.515.000 TL' '474.000 TL' '352.000 TL' '357.000 TL' '423.000 TL'
#  '310.000 TL' '648.000 TL' '3.050.000 TL' '1.525.000 TL' '218.000 TL'
#  '182.000 TL' '160.000 TL' '675.500 TL' '325.500 TL' '4.400.000 TL'
#  '858.000 TL' '4.350.000 TL' '3.700.000 TL' '2.590.000 TL' '3.650.000 TL'
#  '2.450.000 TL' '643.000 TL' '1.075.000 TL' '1.045.000 TL' '613.000 TL'
#  '232.500 TL' '295.600 TL' '102.000 TL' '519.000 TL' '1.115.000 TL'
#  '1.215.000 TL' '1.111.111 TL' '2.750.000 TL' '226.000 TL' '837.000 TL'
#  '529.999 TL' '569.000 TL' '349.000 TL' '369.950 TL' '799.999 TL'
#  '125.000 TL' '1.125.000 TL' '386.000 TL' '487.000 TL' '1.210.000 TL'
#  '2.285.000 TL' '312.000 TL' '775.900 TL' '285.500 TL' '1.230.000 TL'
#  '805.000 TL' '930.000 TL' '746.000 TL' '1.245.000 TL' '830.000 TL'
#  '869.000 TL' '2.250.000 TL' '263.000 TL' '373.000 TL' '1.399.000 TL'
#  '517.500 TL' '238.000 TL' '230.000 TL' '143.000 TL' '1.329.650 TL'
#  '199.999 TL' '209.000 TL' '1.310.000 TL' '1.395.000 TL' '198.000 TL'
#  '1.069.750 TL' '189.500 TL' '5.250.000 TL' '170.000 TL' '1.460.000 TL'
#  '167.000 TL' '1.575.000 TL' '1.600.000 TL' '140.600 TL' '120.000 TL'
#  '2.050.000 TL' '100.000 TL' '105.000 TL' '90.000 TL' '80.000 TL'
#  '1.730.000 TL' '2.175.000 TL' '1.840.000 TL' '2.150.000 TL'
#  '2.875.000 TL' '404.000 TL' '1.695.000 TL' '429.000 TL' '261.000 TL'
#  '129.000 TL' '159.000 TL' '676.000 TL' '462.500 TL' '468.900 TL'
#  '459.900 TL' '840.000 TL' '1.325.000 TL' '1.410.000 TL' '1.360.000 TL'
#  '1.870.000 TL' '384.000 TL' '402.500 TL' '582.500 TL' '198.750 TL'
#  '2.490.000 TL' '4.480.000 TL' '604.000 TL' '668.000 TL' '1.535.750 TL'
#  '381.000 TL' '999.000 TL' '507.000 TL' '829.750 TL' '1.748.000 TL'
#  '257.500 TL' '847.500 TL' '5.195.000 TL' '719.750 TL' '518.000 TL'
#  '4.550.000 TL' '1.039.750 TL' '709.999 TL' '1.029.000 TL' '3.350.000 TL'
#  '1.445.000 TL' '319.500 TL' '153.000 TL' '1.810.000 TL' '2.200.000 TL'
#  '1.295.000 TL' '2.299.000 TL' '1.085.000 TL' '795.900 TL' '969.000 TL'
#  '1.590.000 TL' '329.075 TL' '1.149.000 TL' '3.770.000 TL' '599.750 TL'
#  '258.500 TL' '555.555 TL' '767.500 TL' '649.750 TL' '1.820.000 TL'
#  '1.120.000 TL' '327.000 TL' '1.597.500 TL' '115.000 TL' '4.275.000 TL'
#  '2.735.000 TL' '307.500 TL' '299.900 TL' '2.550.000 TL' '3.890.000 TL'
#  '1.415.000 TL' '1.510.000 TL' '2.419.900 TL' '2.295.000 TL'
#  '1.082.900 TL' '1.759.900 TL' '1.815.000 TL' '636.500 TL' '693.000 TL'
#  '1.330.000 TL' '2.085.000 TL' '609.000 TL' '194.000 TL' '1.649.000 TL'
#  '1.039.000 TL' '972.000 TL' '2.645.000 TL' '537.500 TL' '4.089.900 TL'
#  '1.040.000 TL' '967.500 TL' '559.500 TL' '389.950 TL' '765.500 TL'
#  '654.000 TL' '629.500 TL' '168.000 TL' '669.900 TL' '919.900 TL'
#  '128.500 TL' '559.000 TL' '619.000 TL' '769.000 TL' '659.000 TL'
#  '552.000 TL' '889.900 TL' '297.500 TL' '1.685.000 TL' '345.900 TL'
#  '348.750 TL' '348.000 TL' '673.000 TL' '739.999 TL' '445.000 TL'
#  '248.000 TL' '1.299.999 TL' '1.499.999 TL' '749.999 TL' '349.999 TL'
#  '418.000 TL' '437.000 TL' '1.620.000 TL' '139.999 TL' '857.000 TL'
#  '449.500 TL' '459.000 TL' '1.217.000 TL' '571.000 TL' '1.850.000 TL'
#  '1.720.000 TL' '839.500 TL' '1.169.000 TL' '2.375.000 TL' '549.750 TL'
#  '878.000 TL' '637.000 TL' '973.000 TL' '395.750 TL' '867.000 TL'
#  '719.900 TL' '4.048.500 TL' '759.000 TL' '888.000 TL' '528.750 TL'
#  '949.000 TL' '845.750 TL' '519.500 TL' '284.000 TL' '1.159.900 TL'
#  '1.329.000 TL' '437.500 TL' '1.192.000 TL' '2.950.000 TL' '177.750 TL'
#  '2.625.000 TL' '849.500 TL' '1.032.900 TL' '187.500 TL' '718.850 TL'
#  '798.850 TL' '628.850 TL' '762.900 TL' '1.030.900 TL' '1.379.850 TL'
#  '468.000 TL' '1.520.000 TL' '378.500 TL' '1.235.000 TL' '268.000 TL'
#  '1.349.900 TL' '397.500 TL' '1.799.000 TL' '898.000 TL' '989.000 TL'
#  '307.000 TL' '409.610 TL' '430.610 TL' '1.099.610 TL' '3.180.000 TL'
#  '279.000 TL' '1.389.000 TL' '1.779.950 TL' '1.779.000 TL' '3.395.000 TL'
#  '579.900 TL' '1.162.750 TL' '783.000 TL' '3.949.000 TL' '1.875.000 TL'
#  '1.539.900 TL' '372.550 TL' '742.000 TL' '1.470.000 TL' '428.900 TL'
#  '1.279.900 TL' '965.900 TL']

# %%
for col in df.columns: 
    print(col,df[col].nunique())
# Out:
# İlan No 1901
# İlan Tarihi 46
# Marka 42
# Seri 201
# Model 822
# Yıl 44
# Kilometre 661
# Vites Tipi 3
# Yakıt Tipi 5
# Kasa Tipi 9
# Renk 23
# Motor Hacmi 114
# Motor Gücü 120
# Çekiş 4
# Araç Durumu 1
# Ort. Yakıt Tüketimi 71
# Yakıt Deposu 40
# Boya-değişen 66
# Takasa Uygun 3
# Kimden 3
# Fiyat 740

# %% [markdown]
# Şimdi burada bir sorun olduğunu fark ediyoruz. 2500 adet gözlem birimimiz varken 2500 adet farklı ilan numarası olması gerekir, fakat burada 1901 adet ilan numarası var. Bu bize veride gözlem tekrarı olduğunu gösteriyor, dolayısıyla tekrar eden gözlemlerden kurtulmamız gerekiyor.

# %%
df["İlan No"].value_counts()
# Out:
# İlan No
# 27502775    4
# 27502413    4
# 27502816    4
# 27503322    4
# 27502682    4
#            ..
# 27378745    1
# 27378715    1
# 27378714    1
# 27378696    1
# 27498448    1
# Name: count, Length: 1901, dtype: int64

# %%
df=df.drop_duplicates(subset="İlan No")

# %%
df["İlan No"].value_counts()
# Out:
# İlan No
# 27377214    1
# 27502137    1
# 27502169    1
# 27314168    1
# 27314158    1
#            ..
# 27473573    1
# 27498739    1
# 27498868    1
# 27498486    1
# 27498448    1
# Name: count, Length: 1901, dtype: int64

# %%
df["İlan No"].value_counts().max()
# Out:
# np.int64(1)

# %%
df["İlan No"].nunique()
# Out:
# 1901

# %%
len(df)
# Out:
# 1901

# %% [markdown]
# Böylelikle tekrar eden gözlem problemini çözmüş olduk.
